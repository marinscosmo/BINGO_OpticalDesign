# %%
import numpy as np

import OpticalDesign as OD
import ModelDesign as MODEL
import DrawnOpticalDesignModels as DRAWN

import matplotlib
from matplotlib import rc
from matplotlib import cm
import matplotlib.pyplot as plt
# %matplotlib inline

rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)
font = {'family' : 'normal',
        'weight' : 'bold',
        'size'   : 22}
matplotlib.rc('font', **font)

# %%
grid = plt.GridSpec(1,1,top = 2, right=1.)
ax1 = plt.subplot(grid[0,0])
DRAWN.Rectangular(ax=ax1,plot_circle=True)

# %%
grid = plt.GridSpec(1,2,top = 2, right=2.)

ax1 = plt.subplot(grid[0,0])
DRAWN.DoubleRectangular(ax=ax1,plot_circle=True,colorcircle1="gray",colorcircle2="darkgray", including_add_horns=False)

ax2 = plt.subplot(grid[0,1],sharey=ax1)
DRAWN.DoubleRectangular(ax=ax2,plot_circle=True,
                        colorcircle1    = "gray" , colorcircle2   = "darkgray",
                        colorcircle_add = "black", colorhexag_add = "yellow",
                        including_add_horns=True)
plt.gca().invert_yaxis()

# %%
grid = plt.GridSpec(1,1,top = 2, right=1.4)
ax1 = plt.subplot(grid[0,0])
DRAWN.TripleRectangular(ax=ax1,plot_circle=True)

# %%
grid = plt.GridSpec(1,1,top = 2, right=1.4)
ax1 = plt.subplot(grid[0,0])
DRAWN.Hexagonal(ax=ax1,plot_circle=True)

# %% [markdown]
# ### Optical Paper -- FIG 6

# %%
fig  = plt.figure(constrained_layout=True)
grid = plt.GridSpec(2,2,top=3.5,right=2, wspace=0.27, hspace=0.17)

ax1  = plt.subplot(grid[0,0])
DRAWN.Rectangular(ax=ax1,plot_circle=True)

ax2 = plt.subplot(grid[0,1])
DRAWN.DoubleRectangular(ax=ax2,plot_circle=True, lshexag_add="dashed", lscircle_add ="dashed")

ax3 = plt.subplot(grid[1,0])
DRAWN.TripleRectangular(ax=ax3,plot_circle=True)

ax4  = plt.subplot(grid[1,1])
DRAWN.Hexagonal(ax=ax4,plot_circle=True)


plt.savefig("FocalPlaneDesign_used", dpi=50, bbox_inches='tight');
# Out:
# /home/marins/.local/lib/python3.6/site-packages/ipykernel_launcher.py:17: UserWarning: Calling figure.constrained_layout, but figure not setup to do constrained layout.  You either called GridSpec without the fig keyword, you are using plt.subplot, or you need to call figure or subplots with the constrained_layout=True kwarg.
